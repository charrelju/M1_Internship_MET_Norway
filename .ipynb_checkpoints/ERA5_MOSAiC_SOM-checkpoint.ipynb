# %% [markdown]
# <div style="text-align:right;">Justine Charrel - Master 1 Internship</div>

# %% [markdown]
# This scrupt is used to realize unsupervised machine learning (self-organizing maps) of temperature of ERA5.

# %%
from netCDF4 import Dataset as ncfile
from minisom import MiniSom
import matplotlib.pyplot as plt
import time
import numpy as np
from sklearn.metrics import mean_squared_error
from matplotlib.pyplot import cm
from pylab import pcolor
import matplotlib as mpl

# %%
ppidir = '/lustre/storeB/users/justinec/master_internship/data/ERA5_MOSAiC/'
data_link  = ppidir + 'concatenated_ERA5_MOSAiC.nc'

dataset = ncfile(data_link,'r')    #dataset of radiosoundings of MOSAiC and ERA5

# %%
dataset
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): pres(29), time(1399)
#     variables(dimensions): float64 pres(pres), float64 temp_era5(time, pres), float64 temp_mosaic(time, pres), float64 rh_era5(time, pres), float64 rh_mosaic(time, pres), float64 wspeed_era5(time, pres), float64 wspeed_mosaic(time, pres), float64 wdir_era5(time, pres), float64 wdir_mosaic(time, pres), float64 lat_mosaic(time, pres), float64 lon_mosaic(time, pres), float64 time_mosaic(time, pres)
#     groups:

# %%
pres = dataset.variables['pres'][:]
data = dataset.variables['temp_era5'][:]

# %%
# set hyperparameters
grid_rows = 4
grid_colums = 4
iterations = 100000
sigma = 1 #1 seems great, let's see when changing others parameters
learning_rate = 0.05

# %%
# initialiation
som = MiniSom(grid_rows, grid_colums, input_len=len(data[1]), sigma=sigma, learning_rate=learning_rate) # initialization of 6x6 SOM
som.random_weights_init(data)

# %%
# training
start_time = time.time()
som.train_batch(data,iterations) # trains the SOM with 100 iterations
elapsed_time = time.time() - start_time
print(elapsed_time, "seconds")
# Out:
# 12.743458271026611 seconds

# %%
q_error = som.quantization_error(data)

# %%
neuron_weights = som.get_weights()

# %%
win_map = som.win_map(data)

# %%
#######################
# Q-ERROR
#######################

# %%
quantization_errors = np.linalg.norm(som.quantization(data) - data, axis=1)

# %%
quantization_errors
# Out:
# array([4.65632012, 4.82076274, 5.49058448, ..., 6.81296793, 6.50701702,
#        7.3575685 ])

# %%
mean_squared_error(data[0],a[-1])
# Out:
# 4.505228331792976

# %%
a = som.quantization(data) #BMU for each temperature profile

# %%
a[0]
# Out:
# array([219.48122498, 222.73492894, 225.98584746, 229.16409483,
#        232.34303943, 235.10278026, 237.86962069, 240.23671621,
#        242.60358439, 244.64036579, 246.68067102, 248.42262971,
#        250.16867216, 251.75596508, 253.33922704, 254.81930371,
#        256.29900278, 257.40222129, 258.50478336, 259.44448469,
#        260.49810281, 261.53094783, 262.29041556, 262.56063275,
#        262.98321375, 263.40691714, 263.13078275, 263.62046012,
#        264.02151673])

# %%
#######################
# Q-ERROR
#######################

# %%
#######################
# COLOR
#######################

# %%
som.distance_map()
# Out:
# array([[0.24942272, 0.54681451, 0.44814227, 0.33604117],
#        [0.60333424, 0.98805511, 0.98911364, 0.66570388],
#        [0.52295758, 0.87878143, 1.        , 0.68094655],
#        [0.2627786 , 0.36320777, 0.43914147, 0.24932032]])

# %%
color=iter(cm.rainbow(som.distance_map()))

# %%
def colorFader(c1,c2,mix=0): #fade (linear interpolate) from color c1 (at mix=0) to c2 (mix=1)
    c1=np.array(mpl.colors.to_rgb(c1))
    c2=np.array(mpl.colors.to_rgb(c2))
    return mpl.colors.to_hex((1-mix)*c1 + mix*c2)

# %%
c1='red' #blue
c2='blue' #green

# %%
pcolor(som.distance_map().T)

# %%
#######################
# COLOR
#######################

# %%
parameters = {'axes.labelsize':10, 'axes.titlesize':10, 'legend.fontsize':16, 'xtick.labelsize':10, 'ytick.labelsize':10, 
                  'legend.title_fontsize':10, 'figure.titlesize':25}
plt.rcParams.update(parameters)

fig, axs = plt.subplots(grid_colums,grid_rows,figsize=(15,15))
winner_list = []
for ix in range(len(data)):
    winner = som.winner(data[ix])
    winner_list.append(winner)

t=0
for i in range(0,grid_colums) :
     for n in range(0,grid_rows) :
        for m in range(len(win_map[(i,n)])) :
            axs[i,n].plot(win_map[(i,n)][m], pres, color=colorFader(c1,c2,t/15), alpha=0.5)
        t = t+1
        axs[i,n].plot(neuron_weights[i][n], pres, 'k')
        axs[i,n].invert_yaxis()
        axs[i,n].grid()
        axs[i,n].set_title('Neuron #'+str(t), fontsize=10, pad=20, weight='bold')
        axs[i,n].text(0.5,1.05, str(len(win_map[(i,n)])) + ' profiles',horizontalalignment='center',verticalalignment='center',transform = axs[i,n].transAxes)
        if n==0 :
            axs[i,n].set_ylabel('Pressure [hPa]')
        if i>2 :
            axs[i,n].set_xlabel('Temperature [K]')
            
fig.tight_layout()        
fig.subplots_adjust(top=0.93, hspace=0.35)
fig.legend(title='q-error = '+str(np.round(q_error)))
path_fig = '/lustre/storeB/users/justinec/master_internship/figures/era5_mosaic_SOM/'
plt.savefig(path_fig+'ERA5_temp_SOM_s'+str(sigma)+'_lt'+str(learning_rate)+'_i'+str(iterations)+'.png',dpi=300)
# Out:
# 0.0
# 0.06666666666666667
# 0.13333333333333333
# 0.2
# 0.26666666666666666
# 0.3333333333333333
# 0.4
# 0.4666666666666667
# 0.5333333333333333
# 0.6
# 0.6666666666666666
# 0.7333333333333333
# 0.8
# 0.8666666666666667
# 0.9333333333333333
# 1.0
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
