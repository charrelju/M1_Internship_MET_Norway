# %% [markdown]
# <div style="text-align:right;">Justine Charrel - Master 1 Internship</div>

# %% [markdown]
# This script concatanate all the collocated data of IFS and MOSAiC.

# %% [markdown]
# ### IMPORT

# %%
import glob
import xarray
from netCDF4 import Dataset as ncfile
import numpy as np
from netCDF4 import num2date
import matplotlib.dates as dates

# %%
years = ['2019','2020'] ; months = ['01','02','03','04','05','06','07','08','09','10','11','12']
paths = []
for year in years:
    for month in months :
        path = sorted(glob.glob('/lustre/storeB/users/justinec/master_internship/data/IFS_MOSAiC/' + year + '/' + month + '/collocated_IFS_MOSAiC_*.nc'))
        if path :
            for i in range(len(path)) :
                paths.append(path[i])

# %%
ds = xarray.open_mfdataset(paths,combine = 'nested', concat_dim="time")

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:        (pres: 15, time: 8122)
# Coordinates:
#   * pres           (pres) float64 1e+03 950.0 900.0 850.0 ... 400.0 350.0 300.0
# Dimensions without coordinates: time
# Data variables: (12/13)
#     temp_ifs       (time, pres) float64 dask.array<chunksize=(1, 15), meta=np.ndarray>
#     temp_mosaic    (time, pres) float64 dask.array<chunksize=(1, 15), meta=np.ndarray>
#     rh_ifs         (time, pres) float64 dask.array<chunksize=(1, 15), meta=np.ndarray>
#     rh_mosaic      (time, pres) float64 dask.array<chunksize=(1, 15), meta=np.ndarray>
#     wspeed_ifs     (time, pres) float64 dask.array<chunksize=(1, 15), meta=np.ndarray>
#     wspeed_mosaic  (time, pres) float64 dask.array<chunksize=(1, 15), meta=np.ndarray>
#     ...             ...
#     wdir_mosaic    (time, pres) float64 dask.array<chunksize=(1, 15), meta=np.ndarray>
#     lat_mosaic     (time, pres) float64 dask.array<chunksize=(1, 15), meta=np.ndarray>
# ...

# %%
path_output = '/lustre/storeB/users/justinec/master_internship/data/IFS_MOSAiC/'
output_filename = path_output + '/concatenated_IFS_MOSAiC.nc'

# %%
ds.to_netcdf(output_filename)

# %%
test = ncfile('/lustre/storeB/users/justinec/master_internship/data/IFS_MOSAiC/concatenated_IFS_MOSAiC.nc')
